# %% [markdown]
# <a href="https://colab.research.google.com/github/abhirupinspace/Fake_True_News_TestML/blob/main/True_fake1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
true = pd.read_csv('True.csv')

# %%
fake = pd.read_csv('Fake.csv')

# %%
true.head()
# Out:
#                                                title  \
# 0  As U.S. budget fight looms, Republicans flip t...
# 1  U.S. military to accept transgender recruits o...
# 2  Senior U.S. Republican senator: 'Let Mr. Muell...
# 3  FBI Russia probe helped by Australian diplomat...
# 4  Trump wants Postal Service to charge 'much mor...
#
#                                                 text       subject  \
# 0  WASHINGTON (Reuters) - The head of a conservat...  politicsNews
# 1  WASHINGTON (Reuters) - Transgender people will...  politicsNews
# 2  WASHINGTON (Reuters) - The special counsel inv...  politicsNews
# 3  WASHINGTON (Reuters) - Trump campaign adviser ...  politicsNews
# 4  SEATTLE/WASHINGTON (Reuters) - President Donal...  politicsNews
#
#                  date
# 0  December 31, 2017
# 1  December 29, 2017
# 2  December 31, 2017
# 3  December 30, 2017
# 4  December 29, 2017

# %%
fake.head()
# Out:
#                                                title  \
# 0   Donald Trump Sends Out Embarrassing New Year’...
# 1   Drunk Bragging Trump Staffer Started Russian ...
# 2   Sheriff David Clarke Becomes An Internet Joke...
# 3   Trump Is So Obsessed He Even Has Obama’s Name...
# 4   Pope Francis Just Called Out Donald Trump Dur...
#
#                                                 text subject  \
# 0  Donald Trump just couldn t wish all Americans ...    News
# 1  House Intelligence Committee Chairman Devin Nu...    News
# 2  On Friday, it was revealed that former Milwauk...    News
# 3  On Christmas day, Donald Trump announced that ...    News
# 4  Pope Francis used his annual Christmas Day mes...    News
#
#                 date
# 0  December 31, 2017
# 1  December 31, 2017
# 2  December 30, 2017
# 3  December 29, 2017
# 4  December 25, 2017

# %%
true['label'] = 1
fake['label'] = 0

# %%
news = pd.concat([true, fake], axis=0)

# %%
news.head()
# Out:
#                                                title  \
# 0  As U.S. budget fight looms, Republicans flip t...
# 1  U.S. military to accept transgender recruits o...
# 2  Senior U.S. Republican senator: 'Let Mr. Muell...
# 3  FBI Russia probe helped by Australian diplomat...
# 4  Trump wants Postal Service to charge 'much mor...
#
#                                                 text       subject  \
# 0  WASHINGTON (Reuters) - The head of a conservat...  politicsNews
# 1  WASHINGTON (Reuters) - Transgender people will...  politicsNews
# 2  WASHINGTON (Reuters) - The special counsel inv...  politicsNews
# 3  WASHINGTON (Reuters) - Trump campaign adviser ...  politicsNews
# 4  SEATTLE/WASHINGTON (Reuters) - President Donal...  politicsNews
#
#                  date  label
# 0  December 31, 2017       1
# 1  December 29, 2017       1
# 2  December 31, 2017       1
# 3  December 30, 2017       1
# 4  December 29, 2017       1

# %%
news.tail()
# Out:
#                                                    title  \
# 23476  McPain: John McCain Furious That Iran Treated ...
# 23477  JUSTICE? Yahoo Settles E-mail Privacy Class-ac...
# 23478  Sunnistan: US and Allied ‘Safe Zone’ Plan to T...
# 23479  How to Blow $700 Million: Al Jazeera America F...
# 23480  10 U.S. Navy Sailors Held by Iranian Military ...
#
#                                                     text      subject  \
# 23476  21st Century Wire says As 21WIRE reported earl...  Middle-east
# 23477  21st Century Wire says It s a familiar theme. ...  Middle-east
# 23478  Patrick Henningsen  21st Century WireRemember ...  Middle-east
# 23479  21st Century Wire says Al Jazeera America will...  Middle-east
# 23480  21st Century Wire says As 21WIRE predicted in ...  Middle-east
#
#                    date  label
# 23476  January 16, 2016      0
# 23477  January 16, 2016      0
# 23478  January 15, 2016      0
# 23479  January 14, 2016      0
# 23480  January 12, 2016      0

# %%
news.isnull().sum()
# Out:
# title      0
# text       0
# subject    0
# date       0
# label      0
# dtype: int64

# %%
news= news.drop(['title', 'subject'], axis=1)

# %%
news.head()
# Out:
#                                                 text                date  \
# 0  WASHINGTON (Reuters) - The head of a conservat...  December 31, 2017
# 1  WASHINGTON (Reuters) - Transgender people will...  December 29, 2017
# 2  WASHINGTON (Reuters) - The special counsel inv...  December 31, 2017
# 3  WASHINGTON (Reuters) - Trump campaign adviser ...  December 30, 2017
# 4  SEATTLE/WASHINGTON (Reuters) - President Donal...  December 29, 2017
#
#    label
# 0      1
# 1      1
# 2      1
# 3      1
# 4      1

# %%
news = news.sample(frac=1)

# %%
news.reset_index(inplace=True)

# %%
news.head()
# Out:
#    index                                               text  \
# 0  21921  Looking back on the 2016 Presidential election...
# 1   9676  Hillary Clinton praised London s socialized me...
# 2  20406  MOGADISHU (Reuters) - At least one person was ...
# 3  20344  OSLO (Reuters) - Norway s tax-cutting Conserva...
# 4   9144  WHAT S WRONG WITH THESE PEOPLE? Clinton Crony ...
#
#                   date  label
# 0    December 30, 2017      0
# 1         Oct 16, 2017      0
# 2  September 11, 2017       1
# 3  September 10, 2017       1
# 4         Dec 21, 2017      0

# %%
news.drop(['index'], axis=1, inplace=True)

# %%
news.head()
# Out:
#                                                 text                 date  \
# 0  Looking back on the 2016 Presidential election...    December 30, 2017
# 1  Hillary Clinton praised London s socialized me...         Oct 16, 2017
# 2  MOGADISHU (Reuters) - At least one person was ...  September 11, 2017
# 3  OSLO (Reuters) - Norway s tax-cutting Conserva...  September 10, 2017
# 4  WHAT S WRONG WITH THESE PEOPLE? Clinton Crony ...         Dec 21, 2017
#
#    label
# 0      0
# 1      0
# 2      1
# 3      1
# 4      0

# %%
import re

# %%
def wordopt(text):
  text = text.lower()
  text = re.sub('\[.*?\]', '', text)
  text = re.sub("\\W", " ", text)
  text = re.sub('https?://\S+|www\.\S+', '', text)
  return text

# %%
news['text'] = news['text'].apply(wordopt)

# %%
x = news['text']
y = news['label']

# %%
y
# Out:
# 0        0
# 1        0
# 2        1
# 3        1
# 4        0
#         ..
# 44893    1
# 44894    1
# 44895    0
# 44896    1
# 44897    1
# Name: label, Length: 44898, dtype: int64

# %%
x
# Out:
# 0        looking back on the 2016 presidential election...
# 1        hillary clinton praised london s socialized me...
# 2        mogadishu  reuters    at least one person was ...
# 3        oslo  reuters    norway s tax cutting conserva...
# 4        what s wrong with these people  clinton crony ...
#                                ...
# 44893    new york  reuters    a leading u s  promoter o...
# 44894    new york  reuters    a proposal driven by pres...
# 44895     it turns out the hypocrite  liberal  golden s...
# 44896    berlin  reuters    german chancellor angela me...
# 44897    london  reuters    prime minister theresa may ...
# Name: text, Length: 44898, dtype: object

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.3)

# %%
x_train.shape
# Out:
# (31428,)

# %%
x_test.shape
# Out:
# (13470,)

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
vectorization = TfidfVectorizer()

# %%
xv_train = vectorization.fit_transform(x_train)

# %%
xv_test= vectorization.transform(x_test)

# %%
xv_train
# Out:
# <31428x104780 sparse matrix of type '<class 'numpy.float64'>'
# 	with 6571603 stored elements in Compressed Sparse Row format>

# %%
xv_test
# Out:
# <13470x104780 sparse matrix of type '<class 'numpy.float64'>'
# 	with 2800973 stored elements in Compressed Sparse Row format>

# %%
from sklearn.linear_model import LogisticRegression

# %%
LR = LogisticRegression()

# %%
LR.fit(xv_train, y_train)
# Out:
# LogisticRegression()

# %%
pred_lr = LR.predict(xv_test)

# %%
LR.score(xv_test, y_test)
# Out:
# 0.9878247958426132

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import classification_report

# %%
DTC = DecisionTreeClassifier()

# %%
DTC.fit(xv_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
pred_dtc = DTC.predict(xv_test)

# %%
DTC.score(xv_test, y_test)
# Out:
# 0.9965850037119525

# %%
print(classification_report(y_test, pred_dtc))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      7012
#            1       1.00      1.00      1.00      6458
#
#     accuracy                           1.00     13470
#    macro avg       1.00      1.00      1.00     13470
# weighted avg       1.00      1.00      1.00     13470

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rfc = RandomForestClassifier()

# %%
rfc.fit(xv_train, y_train)
# Out:
# RandomForestClassifier()

# %%
predict_rfc = rfc.predict(xv_test)

# %%
rfc.score(xv_test, y_test)
# Out:
# 0.9900519673348182

# %%
print(classification_report(y_test, predict_rfc))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      0.99      0.99      7012
#            1       0.99      0.99      0.99      6458
#
#     accuracy                           0.99     13470
#    macro avg       0.99      0.99      0.99     13470
# weighted avg       0.99      0.99      0.99     13470

# %%
from sklearn.ensemble import GradientBoostingClassifier

# %%
gbc= GradientBoostingClassifier()

# %%
gbc.fit(xv_train, y_train)

# %%
pred_gbc = gbc.predict(xv_test)

# %%
gbc.score(xv_test, y_test)

# %%
print(classification_report(y_test, predict_gbc))

# %%
def output_lable(n):
  if n == 0:
    return "Fake News"
  elif n == 1:
    return "Not A Fake News"
